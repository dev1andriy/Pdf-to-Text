# %% [markdown]
# ##### https://www.tutorialspoint.com/python_text_processing/python_synonyms_and_antonyms.htm

# %%
pip install translate
# Out:
# Collecting translate
#   Downloading https://files.pythonhosted.org/packages/85/b2/2ea329a07bbc0c7227eef84ca89ffd6895e7ec237d6c0b26574d56103e53/translate-3.5.0-py2.py3-none-any.whl
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from translate) (2.23.0)
# Collecting tox
#   Downloading https://files.pythonhosted.org/packages/c6/36/b0e6016724ae598ba30168618a91d3ee2d7510c20cb05deb8cdc3f7d53b3/tox-3.15.2-py2.py3-none-any.whl (137kB)
#      |████████████████████████████████| 143kB 8.3MB/s
# Collecting pre-commit
#   Downloading https://files.pythonhosted.org/packages/50/38/1e3387cf2621e560c59364f01d3c0b8443ee0c07a4c003502f07a8f372df/pre_commit-2.5.1-py2.py3-none-any.whl (171kB)
#      |████████████████████████████████| 174kB 12.0MB/s
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from translate) (7.1.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.6/dist-packages (from translate) (4.2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->translate) (2020.4.5.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->translate) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->translate) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->translate) (3.0.4)
# Collecting six>=1.14.0
#   Downloading https://files.pythonhosted.org/packages/ee/ff/48bde5c0f013094d729fe4b0316ba2a24774b3ff1c52d924a8a4cb04078a/six-1.15.0-py2.py3-none-any.whl
# Requirement already satisfied: packaging>=14 in /usr/local/lib/python3.6/dist-packages (from tox->translate) (20.4)
# Collecting virtualenv!=20.0.0,!=20.0.1,!=20.0.2,!=20.0.3,!=20.0.4,!=20.0.5,!=20.0.6,!=20.0.7,>=16.0.0
#   Downloading https://files.pythonhosted.org/packages/f0/55/f0de23cb61f2e90db3f8362f0e685a0bc04d0c4cb159b7a96cb7c4817d63/virtualenv-20.0.23-py2.py3-none-any.whl (4.7MB)
#      |████████████████████████████████| 4.7MB 14.2MB/s
# Requirement already satisfied: importlib-metadata<2,>=0.12; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from tox->translate) (1.6.1)
# Requirement already satisfied: py>=1.4.17 in /usr/local/lib/python3.6/dist-packages (from tox->translate) (1.8.1)
# Requirement already satisfied: filelock>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from tox->translate) (3.0.12)
# Collecting pluggy>=0.12.0
#   Downloading https://files.pythonhosted.org/packages/a0/28/85c7aa31b80d150b772fbe4a229487bc6644da9ccb7e427dd8cc60cb8a62/pluggy-0.13.1-py2.py3-none-any.whl
# Collecting toml>=0.9.4
#   Downloading https://files.pythonhosted.org/packages/9f/e1/1b40b80f2e1663a6b9f497123c11d7d988c0919abbf3c3f2688e448c5363/toml-0.10.1-py2.py3-none-any.whl
# Collecting identify>=1.0.0
#   Downloading https://files.pythonhosted.org/packages/35/4f/20c79034a02f505f7d5fa4910d5d78f8af74346821d3fda5d21db34f99fb/identify-1.4.19-py2.py3-none-any.whl (97kB)
#      |████████████████████████████████| 102kB 9.4MB/s
# Collecting cfgv>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/6d/82/49913e721128ff16d6b7cf304f513de7bba698583b045dfb9c4b3bb2f467/cfgv-3.1.0-py2.py3-none-any.whl
# Collecting pyyaml>=5.1
#   Downloading https://files.pythonhosted.org/packages/64/c2/b80047c7ac2478f9501676c988a5411ed5572f35d1beff9cae07d321512c/PyYAML-5.3.1.tar.gz (269kB)
#      |████████████████████████████████| 276kB 45.2MB/s
# Collecting nodeenv>=0.11.1
#   Downloading https://files.pythonhosted.org/packages/0d/54/538edbe88c87f6cd71f009145a56264622de84508f6ad1ae4d76976f47be/nodeenv-1.4.0-py2.py3-none-any.whl
# Collecting importlib-resources; python_version < "3.7"
#   Downloading https://files.pythonhosted.org/packages/ce/06/94cb4028cbcb834c3a6a0c239ab37e76e293c75bed51a9cee2cb8337b47e/importlib_resources-2.0.1-py2.py3-none-any.whl
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging>=14->tox->translate) (2.4.7)
# Collecting appdirs<2,>=1.4.3
#   Downloading https://files.pythonhosted.org/packages/3b/00/2344469e2084fb287c2e0b57b72910309874c3245463acd6cf5e3db69324/appdirs-1.4.4-py2.py3-none-any.whl
# Collecting distlib<1,>=0.3.0
#   Downloading https://files.pythonhosted.org/packages/7d/29/694a3a4d7c0e1aef76092e9167fbe372e0f7da055f5dcf4e1313ec21d96a/distlib-0.3.0.zip (571kB)
#      |████████████████████████████████| 573kB 40.2MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata<2,>=0.12; python_version < "3.8"->tox->translate) (3.1.0)
# Building wheels for collected packages: pyyaml, distlib
#   Building wheel for pyyaml (setup.py) ... done
#   Created wheel for pyyaml: filename=PyYAML-5.3.1-cp36-cp36m-linux_x86_64.whl size=44621 sha256=5a530f517f0946bc1df47340a25218175f0d188f561584d93abe1fad17cc181f
#   Stored in directory: /root/.cache/pip/wheels/a7/c1/ea/cf5bd31012e735dc1dfea3131a2d5eae7978b251083d6247bd
#   Building wheel for distlib (setup.py) ... done
#   Created wheel for distlib: filename=distlib-0.3.0-cp36-none-any.whl size=340429 sha256=04245b6aef90d428743ff001bc68fb2a831ead2a3c6243b282620fdba19a4ec8
#   Stored in directory: /root/.cache/pip/wheels/6e/e8/db/c73dae4867666e89ba3cfbc4b5c092446f0e584eda6f409cbb
# Successfully built pyyaml distlib
# ERROR: pytest 3.6.4 has requirement pluggy<0.8,>=0.5, but you'll have pluggy 0.13.1 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement six~=1.12.0, but you'll have six 1.15.0 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: six, appdirs, distlib, importlib-resources, virtualenv, pluggy, toml, tox, identify, cfgv, pyyaml, nodeenv, pre-commit, translate
#   Found existing installation: six 1.12.0
#     Uninstalling six-1.12.0:
#       Successfully uninstalled six-1.12.0
#   Found existing installation: pluggy 0.7.1
#     Uninstalling pluggy-0.7.1:
#       Successfully uninstalled pluggy-0.7.1
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed appdirs-1.4.4 cfgv-3.1.0 distlib-0.3.0 identify-1.4.19 importlib-resources-2.0.1 nodeenv-1.4.0 pluggy-0.13.1 pre-commit-2.5.1 pyyaml-5.3.1 six-1.15.0 toml-0.10.1 tox-3.15.2 translate-3.5.0 virtualenv-20.0.23

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from bson.objectid import ObjectId
import pandas as pd
import os

# %%
data_path = '/content/drive/My Drive/data/'

# %%
class Word():
  word = ''
  stemming = ''
  pos_tag = ''
  tag_desc = ''
  count = 0
  book_id = ObjectId
  is_training = False
  is_learned = False
  translate = ''

  def __init__(self):
    pass

  def __repr__(self):
    return f'{self.word} - {self.count}\nstemming: {self.stemming}\npos_tag: {self.pos_tag}\ntag_desc: {self.tag_desc}\n\n'

# %% [markdown]
# ### work with human language data

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from nltk.tag import pos_tag

from translate import Translator

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %% [markdown]
# describes some constants to work with text

# %%
tags_desc = {
        'CC': 'coordinating conjunction',
        'CD': 'cardinal digit',
        'DT': 'determiner',
        'EX': 'existential there (like: “there is” … think of it like “there exists”)',
        'FW': 'foreign word',
        'IN': 'preposition/subordinating conjunction',
        'JJ': 'adjective ‘big’',
        'JJR': 'adjective, comparative ‘bigger’',
        'JJS': 'adjective, superlative ‘biggest’',
        'LS': 'list marker 1)',
        'MD': 'modal could, will',
        'NN': 'noun, singular ‘desk’',
        'NNS': 'noun plural ‘desks’',
        'NNP': 'proper noun, singular ‘Harrison’',
        'NNPS': 'proper noun, plural ‘Americans’',
        'PDT': 'predeterminer ‘all the kids’',
        'POS': 'possessive ending parent’s',
        'PRP': 'personal pronoun I, he, she',
        'PRP$': 'possessive pronoun my, his, hers',
        'RB': 'adverb very, silently,',
        'RBR': 'adverb, comparative better',
        'RBS': 'adverb, superlative best',
        'RP': 'particle give up',
        'TO': 'to go ‘to’ the store.',
        'UH': 'interjection, errrrrrrrm',
        'VB': 'verb, base form take',
        'VBD': 'verb, past tense took',
        'VBG': 'verb, gerund/present participle taking',
        'VBN': 'verb, past participle taken',
        'VBP': 'verb, sing. present, non-3d take',
        'VBZ': 'verb, 3rd person sing. present takes',
        'WDT': 'wh-determiner which',
        'WP': 'wh-pronoun who, what',
        'WP$': 'possessive wh-pronoun whose',
        'WRB': 'wh-abverb where, when',
        '': 'none',
        '.': 'none'
    }

# %%
stop_words = stopwords.words('english')

# %%
punctuations = ['(', ')', ';', ':', '[', ']', '!', '?', ',', '!', '=', '==', '<', '>', '@', '#', '$', '%', '^',
                        '&', '*',
                        '.', '//', '{', '}', '...', '``', '+', "''", ]

# %% [markdown]
# ### read file into string

# %%
file_name = 'The Rules of Work.txt'
file_path = data_path + file_name

# %%
with open(file_path, 'r') as file:
    data = file.read()

# %% [markdown]
# ### parse text to object

# %%
def encode_word(word):
    return word.lower().encode('ascii', 'ignore').decode('ascii')

# %%
tokens = word_tokenize(data)

# %%
tokens = [encode_word(word) for word in tokens
                if not word in stop_words
                and not word in punctuations
                and not word.isnumeric()
                and len(word) > 2]

# %%
fdist = FreqDist(tokens)
most_common = fdist.most_common()

# %%
def stemming_word(word):
    pst = PorterStemmer()
    return pst.stem(word)

# %%
def freq_to_obj(word, freq, book_id):
    if not word:
        return Word()

    #translator = Translator()

    postag = pos_tag(word)[0] if len(pos_tag(word)) > 1 else ('', '')
    tag = postag[1]
    desc = tags_desc[tag] if tag in tags_desc else ''
    stemming = stemming_word(word)

    translator = Translator(to_lang="uk")
    translate = translator.translate(word)
    # try:
    #     trans = translator.translate(word, src='en', dest='uk')
    #     translate = trans.text
    # except:
    #     print('can not translate - ' + word)

    wordObj = Word()
    wordObj.word=word
    wordObj.stemming=stemming
    wordObj.pos_tag=tag
    wordObj.tag_desc=desc
    wordObj.count=freq
    wordObj.book_id=book_id
    wordObj.translate=translate
    wordObj.is_training=False
    wordObj.is_learned=False

    return wordObj

# %%
book_id = 1

# %%
words = [freq_to_obj(word, freq, book_id) for word, freq in most_common]

# %% [markdown]
# ### Convert data into dataframe and save it

# %%
df = pd.DataFrame([t.__dict__ for t in words ])

# %%
base = os.path.basename(file_path)
csv_name = os.path.splitext(base)[0]
csv_path = data_path + csv_name + '.csv'

# %%
df.to_csv(csv_path)

# %%
#pip install translate
