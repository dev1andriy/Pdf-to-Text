# %%
pip install translate
# Out:
# ...
#      |████████████████████████████████| 174kB 3.7MB/s
# ...
#      |████████████████████████████████| 143kB 8.4MB/s
# ...
#      |████████████████████████████████| 276kB 8.5MB/s
# ...
#      |████████████████████████████████| 102kB 6.5MB/s
# ...
#      |████████████████████████████████| 4.7MB 8.5MB/s
# ...
#      |████████████████████████████████| 573kB 44.5MB/s
# ...
#   Created wheel for pyyaml: filename=PyYAML-5.3.1-cp36-cp36m-linux_x86_64.whl size=44621 sha256=0b3e13ad2baf1f57f7a9f0e7435db88ac37e3170ce09ed7f4b015eab9453da4a
#   Stored in directory: /root/.cache/pip/wheels/a7/c1/ea/cf5bd31012e735dc1dfea3131a2d5eae7978b251083d6247bd
# ...
#   Created wheel for distlib: filename=distlib-0.3.0-cp36-none-any.whl size=340429 sha256=fbe7b50f56ecb58da9e204fd78269e06f3535d792aa9f665d93c8c513c1051aa
#   Stored in directory: /root/.cache/pip/wheels/6e/e8/db/c73dae4867666e89ba3cfbc4b5c092446f0e584eda6f409cbb
# Successfully built pyyaml distlib
# ...

# %%
from translate import Translator

translator= Translator(to_lang="uk")
translation = translator.translate("How can I say corectly")
translation
# Out:
# 'Як я можу сказати прямо'
